# %% [markdown]
# # 80 CEREALS

# %% [markdown]
# # IMPORT IMPORTANT LIBRABRIES

# %%
import pandas as pd
import numpy as ny
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib.inline

# %% [markdown]
# ## LOADING OF THE DATASET

# %%
df=pd.read_excel('80 cereal.xlsx')
df
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
col_labels={'mfr': 'Manufacturer'}
df.rename(columns=col_labels, inplace=True)
df['Manufacturer'].replace({'N': 'Nabisco', 'A':'American Home Food Products','G': 'General Mills','K': 'Kelloggs','P':'Post',
                   'Q': 'Quaker Oats','R':'Ralston Purina'},inplace=True)
df['type'].replace({'C': 'Cold', 'H': 'Hot'},inplace=True)

# %%
# showing the top five rows of the dataframe
df.head()
# Out:
#                         name    Manufacturer  type  calories  protein  fat  \
# 0                  100% Bran         Nabisco  Cold        70        4    1
# 1          100% Natural Bran     Quaker Oats  Cold       120        3    5
# 2                   All-Bran        Kelloggs  Cold        70        4    1
# 3  All-Bran with Extra Fiber        Kelloggs  Cold        50        4    0
# 4             Almond Delight  Ralston Purina  Cold       110        2    2
#
#    sodium  fiber  carbo  sugars  potass  vitamins  shelf  weight  cups  \
# 0     130   10.0    5.0       6     280        25      3     1.0  0.33
# 1      15    2.0    8.0       8     135         0      3     1.0  1.00
# 2     260    9.0    7.0       5     320        25      3     1.0  0.33
# 3     140   14.0    8.0       0     330        25      3     1.0  0.50
# 4     200    1.0   14.0       8      -1        25      3     1.0  0.75
#
#       rating
# 0  68.402973
# 1  33.983679
# 2  59.425505
# 3  93.704912
# 4  34.384843

# %%
# Show the total number of rows and columns in the data
df.shape
# Out:
# (77, 16)

# %%
# All the information of the type of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          77 non-null     object
#  1   Manufacturer  77 non-null     object
#  2   type          77 non-null     object
#  3   calories      77 non-null     int64
#  4   protein       77 non-null     int64
#  5   fat           77 non-null     int64
#  6   sodium        77 non-null     int64
#  7   fiber         77 non-null     float64
#  8   carbo         77 non-null     float64
#  9   sugars        77 non-null     int64
#  10  potass        77 non-null     int64
#  11  vitamins      77 non-null     int64
#  12  shelf         77 non-null     int64
#  13  weight        77 non-null     float64
#  14  cups          77 non-null     float64
#  15  rating        77 non-null     float64
# dtypes: float64(5), int64(8), object(3)
# memory usage: 9.8+ KB

# %%
# Check for duplicated values
df.duplicated().any()
# Out:
# False

# %% [markdown]
# No duplicate found

# %%
# Checking for missing values
df.isnull().sum()
# Out:
# name            0
# Manufacturer    0
# type            0
# calories        0
# protein         0
# fat             0
# sodium          0
# fiber           0
# carbo           0
# sugars          0
# potass          0
# vitamins        0
# shelf           0
# weight          0
# cups            0
# rating          0
# dtype: int64

# %% [markdown]
# There are no missing values in any of the columns of the dataset. This suggests that the dataset is complete and does not require any imputation or handling of missing data.

# %%
df.nunique()
# Out:
# name            77
# Manufacturer     7
# type             2
# calories        11
# protein          6
# fat              5
# sodium          27
# fiber           13
# carbo           22
# sugars          17
# potass          36
# vitamins         3
# shelf            3
# weight           7
# cups            12
# rating          77
# dtype: int64

# %%
#  Statistical analysis on numerical data
df.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   77.000000  77.000000  77.000000   77.000000  77.000000  77.000000
# mean   106.883117   2.545455   1.012987  159.675325   2.151948  14.597403
# std     19.484119   1.094790   1.006473   83.832295   2.383364   4.278956
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  130.000000   1.000000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.000000
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  77.000000   77.000000   77.000000  77.000000  77.000000  77.000000
# mean    6.922078   96.077922   28.246753   2.207792   1.029610   0.821039
# std     4.444885   71.286813   22.342523   0.832524   0.150477   0.232716
# ...

# %%
# Showing all the columns in the dataset
df.columns
# Out:
# Index(['name', 'Manufacturer', 'type', 'calories', 'protein', 'fat', 'sodium',
#        'fiber', 'carbo', 'sugars', 'potass', 'vitamins', 'shelf', 'weight',
#        'cups', 'rating'],
#       dtype='object')

# %%
nutr_columns=['calories','protein','fat','sodium','fiber','carbo','sugars','potass','vitamins']
corr_matrix=df[nutr_columns].corr()

# %%
# Plot a heatmap to show the Correlation of the Cereal Nurient
plt.figure(figsize = (10,9))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('CEREAL NUTRIENT CORRELATION HEATMAP')
plt.show()

# %% [markdown]
# ### OVERALL DISTRIBUTION OF EACH NUTRIENTS

# %%
# List of all the columns in the dataset
df.columns
# Out:
# Index(['name', 'Manufacturer', 'type', 'calories', 'protein', 'fat', 'sodium',
#        'fiber', 'carbo', 'sugars', 'potass', 'vitamins', 'shelf', 'weight',
#        'cups', 'rating'],
#       dtype='object')

# %%
# Plot a histogram to the numerical visualization of each of the nutrient
df.hist(figsize=(10,10))
plt.tight_layout()
plt.show()

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %%
# Which manuacturer produces cereals with the highest calories?
# Group the manufacturers and calories to calculate the total distribution

df.groupby('Manufacturer')['calories'].sum()
# Out:
# Manufacturer
# American Home Food Products     100
# General Mills                  2450
# Kelloggs                       2500
# Nabisco                         520
# Post                            980
# Quaker Oats                     760
# Ralston Purina                  920
# Name: calories, dtype: int64

# %%
# Name the dataframe
df1= df.groupby('Manufacturer')['calories'].sum()

# %%
plt.figure(figsize= (8,6))
df1.plot(kind='bar', x= 'mfr', ylabel= 'Total', title='OVERALL DISTRIBUTION OF CALORIES')
plt.show()

# %% [markdown]
# Among the manufacturers listed, Kellogg's appears to produce cereals with the highest total calories, totaling 2500 calories.  There is notable variation in the total caloric contribution across manufacturers, ranging from as low as 100 calories for American Home Food Products to as high as 2500 calories for Kellogg's.  Manufacturers such as General Mills, Post, and Quaker Oats have relatively higher total caloric contributions compared to others like Nabisco and American Home Food Products. This suggests that they may cater to consumers seeking cereals with higher energy content or different nutritional profiles.

# %%
# Nutritional content by each manufacturer
# Grouping by 'Manufacturer' and computing the average of each nutrient
average_nutritional_content = df.groupby('Manufacturer')[
    ['calories', 'protein', 'fat', 'sodium', 'fiber', 'carbo', 'sugars', 'potass', 'vitamins']].mean()

# Printing the average nutritional content by each manufacturer
print(average_nutritional_content)
# Out:
#                                calories   protein       fat      sodium  \
# Manufacturer
# American Home Food Products  100.000000  4.000000  1.000000    0.000000
# General Mills                111.363636  2.318182  1.363636  200.454545
# Kelloggs                     108.695652  2.652174  0.608696  174.782609
# Nabisco                       86.666667  2.833333  0.166667   37.500000
# Post                         108.888889  2.444444  0.888889  146.111111
# Quaker Oats                   95.000000  2.625000  1.750000   92.500000
# Ralston Purina               115.000000  2.500000  1.250000  198.125000
#
#                                 fiber      carbo    sugars      potass  \
# Manufacturer
# American Home Food Products  0.000000  16.000000  3.000000   95.000000
# General Mills                1.272727  14.727273  7.954545   85.227273
# Kelloggs                     2.739130  15.130435  7.565217  103.043478
# Nabisco                      4.000000  16.000000  1.833333  120.666667
# ...

# %%
# Grouping by 'Manufacturer' and computing the mean of each nutrient
average_nutritional_content = df.groupby('Manufacturer')[
    ['calories', 'protein', 'fat', 'sodium', 'fiber', 'carbo', 'sugars', 'potass', 'vitamins']].mean().reset_index()

# Reshape the DataFrame for plotting
melted_df = average_nutritional_content.melt(id_vars='Manufacturer', var_name='Nutrient', value_name='Average')

# Plotting using Seaborn
plt.figure(figsize=(12, 8))
sns.barplot(x='Nutrient', y='Average', hue='Manufacturer', data=melted_df)
plt.title("AVERAGE NUTRITIONAL CONTEBT BY MANUFACTURER")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# The average caloric content varies across manufacturers, with Kellogg's having the highest average calories (108.70), followed closely by Ralston Purina (115.00).  Nabisco stands out with the lowest average sugar content (1.83), indicating a potentially healthier option for consumers looking to reduce sugar intake. Nabisco also has the highest average fiber content (4.00), suggesting a focus on fiber-rich products. General Mills has the highest average sodium content (200.45), which may be a concern for individuals monitoring their sodium intake. Quaker Oats, on the other hand, has a relatively lower average sodium content (92.50).Kellogg's and Nabisco have higher average potassium content, indicating a potential focus on products with added potassium. American Home Food Products and Ralston Purina have the highest average vitamin content, suggesting an emphasis on fortified cereals.

# %%
# Which manufacturer has the highest rating?
# Group the manufacturers and the ratings column to calculate the average
df.groupby('Manufacturer')['rating'].mean()
# Out:
# Manufacturer
# American Home Food Products    54.850917
# General Mills                  34.485852
# Kelloggs                       44.038462
# Nabisco                        67.968567
# Post                           41.705744
# Quaker Oats                    42.915990
# Ralston Purina                 41.542997
# Name: rating, dtype: float64

# %%
# Name the dataframe
df2=df.groupby('Manufacturer')['rating'].mean()

# %%
# Plotting a bar chart
plt.figure(figsize= (8,6))
df2.plot(kind='bar', xlabel= 'MANUFACTURER', ylabel= 'AVERAGE RATING', title='AVERAGE RATINGS OF EACH MANUFACTURER')
plt.show()

# %% [markdown]
# Nabisco stands out with the highest average rating (67.97), indicating that their cereal products are generally well-received by consumers. : Despite having the lowest average rating (54.85), American Home Food Products still maintains a relatively positive perception among consumers. General Mills, Kellogg's, Post, Quaker Oats, and Ralston Purina: These manufacturers have average ratings ranging from 34.49 to 42.92. While they may not have the highest average ratings compared to Nabisco, they still demonstrate a moderate level of consumer satisfaction.

# %%
# Since Nabisco is the manufacturer with the highest rating, which of Nabisco product has the highest rating
df[df['Manufacturer']=='Nabisco'][['name','Manufacturer','rating']]
# Out:
#                          name Manufacturer     rating
# 0                   100% Bran      Nabisco  68.402973
# 20     Cream of Wheat (Quick)      Nabisco  64.533816
# 63             Shredded Wheat      Nabisco  68.235885
# 64     Shredded Wheat 'n'Bran      Nabisco  74.472949
# 65  Shredded Wheat spoon size      Nabisco  72.801787
# 68    Strawberry Fruit Wheats      Nabisco  59.363993

# %%
df[df['Manufacturer']=='Nabisco']
# Out:
#                          name Manufacturer  type  calories  protein  fat  \
# 0                   100% Bran      Nabisco  Cold        70        4    1
# 20     Cream of Wheat (Quick)      Nabisco   Hot       100        3    0
# 63             Shredded Wheat      Nabisco  Cold        80        2    0
# 64     Shredded Wheat 'n'Bran      Nabisco  Cold        90        3    0
# 65  Shredded Wheat spoon size      Nabisco  Cold        90        3    0
# 68    Strawberry Fruit Wheats      Nabisco  Cold        90        2    0
#
#     sodium  fiber  carbo  sugars  potass  vitamins  shelf  weight  cups  \
# 0      130   10.0    5.0       6     280        25      3    1.00  0.33
# 20      80    1.0   21.0       0      -1         0      2    1.00  1.00
# 63       0    3.0   16.0       0      95         0      1    0.83  1.00
# 64       0    4.0   19.0       0     140         0      1    1.00  0.67
# 65       0    3.0   20.0       0     120         0      1    1.00  0.67
# ...

# %%
# Naming the dataframe
df3=df[df['Manufacturer']=='Nabisco'][['name','Manufacturer','rating']]

# %%
#plotting a bar chart
plt.figure(figsize= (8,6))
df3.plot(kind='bar', xlabel= 'NAME OF PRODUCT', ylabel= 'RATING', title='PRODUCTS PRODUCED BY NABISCO')
plt.show()

# %% [markdown]
# Among Nabisco's cereal products, "Shredded Wheat 'n'Bran" stands out with the highest rating of 74.47.While "Shredded Wheat 'n'Bran" has the highest rating, other Nabisco products such as "100% Bran" and "Shredded Wheat spoon size" also receive relatively high ratings, indicating a positive reception from consumers.

# %%
#Is there a correlation between the amount of fiber and the rating of the cereals
plt.scatter(df['fiber'],df['rating'])
plt.xlabel('fiber')
plt.ylabel('rating')
plt.show()

# %% [markdown]
# There is a linear relationship between Rating and fiber which shows a positive relationship.

# %%
# What is the protein content based on the shelf content?
import seaborn as sns

#Plot a boxplot
sns.boxplot(x='shelf',y='protein',data=df)
# Out:
# <Axes: xlabel='shelf', ylabel='protein'>

# %%
# Proportion of cereals on each shelf
df.groupby('shelf').size()
# Out:
# shelf
# 1    20
# 2    21
# 3    36
# dtype: int64

# %%
df4=df.groupby('shelf').size()

# %%
df4.plot(kind = 'pie', autopct = '%0.1f%%')
plt.title('PROPORTION OF CEREALS ON EACH SHELF')
# Out:
# Text(0.5, 1.0, 'PROPORTION OF CEREALS ON EACH SHELF')

# %% [markdown]
#  Shelf 3 has the highest proportion of cereals compared to the other shelves, indicating that it may be a preferred location for displaying cereal products. This could be due to factors such as eye-level placement, proximity to other complementary products, or promotional strategies.

# %%
# Is there a relationship between sugar content and shelf
sugars= df['sugars']
shelf= df['shelf']

#create a scatter plot
plt.scatter(shelf,sugars)
plt.xlabel('shelf')
plt.ylabel('sugars(g)')
plt.title('RELATIONSHIP BETWEEN SUGAR CONTENT AND SHELF')
plt.show()

# %%
# Can the types of cereal affect rating?

df[df['type']== 'Hot']
# Out:
#                       name                 Manufacturer type  calories  \
# 20  Cream of Wheat (Quick)                      Nabisco  Hot       100
# 43                   Maypo  American Home Food Products  Hot       100
# 57          Quaker Oatmeal                  Quaker Oats  Hot       100
#
#     protein  fat  sodium  fiber  carbo  sugars  potass  vitamins  shelf  \
# 20        3    0      80    1.0   21.0       0      -1         0      2
# 43        4    1       0    0.0   16.0       3      95        25      2
# 57        5    2       0    2.7   -1.0      -1     110         0      1
#
#     weight  cups     rating
# 20     1.0  1.00  64.533816
# 43     1.0  1.00  54.850917
# 57     1.0  0.67  50.828392

# %%
# Plot a boxplot
sns.boxplot(x='type',y='rating',data=df)
# Out:
# <Axes: xlabel='type', ylabel='rating'>

# %%
# Scatter plot of weight vs. calories
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='weight', y='calories')
plt.title('Weight vs. Calories')
plt.show()

# %%
# What is the total number of cereals on each shelf by manufacturer type?
df.groupby('Manufacturer')['shelf'].value_counts()
# Out:
# Manufacturer                 shelf
# American Home Food Products  2         1
# General Mills                3         9
#                              2         7
#                              1         6
# Kelloggs                     3        12
#                              2         7
#                              1         4
# Nabisco                      1         3
#                              2         2
#                              3         1
# Post                         3         6
#                              1         2
#                              2         1
# Quaker Oats                  3         4
#                              2         3
#                              1         1
# Ralston Purina               3         4
#                              1         4
# Name: count, dtype: int64

# %%
# Group by 'Manufacturer' and count occurrences of 'shelf' values
shelf_counts = df.groupby('Manufacturer')['shelf'].value_counts().unstack()

# Plot stacked bar chart using Seaborn
sns.set_style('whitegrid')  # Set style for better aesthetics
shelf_counts.plot(kind='bar', stacked=True, figsize=(10, 6))
plt.title('Number of Cereals on Each Shelf by Manufacturer')  
plt.xlabel('Manufacturer')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Shelf')
plt.show()

# %% [markdown]
# Kelloggs is the manufacturer with the highest number of cereals and shelf 3 is the highest proportion amongst all the manufacturer except American Home Food Products
