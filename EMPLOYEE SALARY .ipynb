# %% [markdown]
# # EMPLOYEES SALARIES BASED ON JOB ROLES

# %% [markdown]
# ### IMPORT IMPORTANT LIBRARIES

# %%
import pandas as pd
import numpy as ny
import matplotlib.pyplot as plt
import seaborn as sns

#matplotliib inline

# %% [markdown]
# ### LOADING THE DATASET

# %%
df= pd.read_excel('EMPLOYEES SALARY .xlsx')
df
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          607 non-null    int64
#  1   work_year           607 non-null    int64
#  2   experience_level    607 non-null    object
#  3   employment_type     607 non-null    object
#  4   job_title           607 non-null    object
#  5   salary              607 non-null    int64
#  6   salary_currency     607 non-null    object
#  7   salary_in_usd       607 non-null    int64
#  8   employee_residence  607 non-null    object
#  9   remote_ratio        607 non-null    int64
#  10  company_location    607 non-null    object
#  11  company_size        607 non-null    object
# dtypes: int64(5), object(7)
# memory usage: 57.0+ KB

# %%
# Statistical analysis on numerical data
df.describe()
# Out:
#        Unnamed: 0    work_year        salary  salary_in_usd  remote_ratio
# count  607.000000   607.000000  6.070000e+02     607.000000     607.00000
# mean   303.000000  2021.405272  3.240001e+05  112297.869852      70.92257
# std    175.370085     0.692133  1.544357e+06   70957.259411      40.70913
# min      0.000000  2020.000000  4.000000e+03    2859.000000       0.00000
# 25%    151.500000  2021.000000  7.000000e+04   62726.000000      50.00000
# 50%    303.000000  2022.000000  1.150000e+05  101570.000000     100.00000
# 75%    454.500000  2022.000000  1.650000e+05  150000.000000     100.00000
# max    606.000000  2022.000000  3.040000e+07  600000.000000     100.00000

# %% [markdown]
# ### CHECKING FOR MISSING VALUES

# %%
# Checking for missing values
df.isnull().sum()
# Out:
# Unnamed: 0            0
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %% [markdown]
# From the data, there is no missing value found

# %%
#Check for duplicate values in the dataset
df.duplicated().any()
# Out:
# False

# %% [markdown]
# No duplicate values was found in the dataset

# %%
# To know the unique values of all the entries
df.nunique()
# Out:
# Unnamed: 0            607
# work_year               3
# experience_level        4
# employment_type         4
# job_title              50
# salary                272
# salary_currency        17
# salary_in_usd         369
# employee_residence     57
# remote_ratio            3
# company_location       50
# company_size            3
# dtype: int64

# %% [markdown]
# ### VISUALIZATION

# %% [markdown]
# #### SALARY BY EXPERIENCE LEVEL

# %%
# How does salary affect experience level?
df.groupby('experience_level')['salary'].mean().sort_values(ascending= False)

# Replace experience levels with full names
df['experience_level'].replace(
    {'EN': 'Entry Level', 'EX': 'Executive Level', 'MI': 'Mid Level', 'SE': 'Senior Level'}, inplace=True)

# %%
# Let's name it Dataframe 2
df2 = df.groupby('experience_level')['salary'].mean()
df2
# Out:
# experience_level
# Entry Level        264622.454545
# Executive Level    427072.115385
# Mid Level          480617.690141
# Senior Level       213949.353571
# Name: salary, dtype: float64

# %%
# Plot a bar chart
df2.plot()
df2.plot(kind = 'bar')
plt.title('AVERAGE SALARY BY EXPERIENCE LEVEL')
# Out:
# Text(0.5, 1.0, 'AVERAGE SALARY BY EXPERIENCE LEVEL')

# %% [markdown]
# Our analysis shows that Mid-level employees is the peak in average salary. Employees at mid-level positions command the highest average salaries of 480,617. The average salary for Entry-Level positions is approximately 264.622, reflecting the common trend where organizations offer lower initial salaries to employees with limited experience and skillset. The senior level experience category has a lower average salaries which could be because of the differences in job responsibilities or roles or even lack of opportunity for them to advance their skills.

# %% [markdown]
# ### DISTRIBUTION OF AVERAGE SALARIES FOR EMPLOYEES IN EACH EMPLOYMENT TYPE CATEGORY

# %%
# How does the average salary vary by experience level?
df.groupby('employment_type')['salary'].mean()

# Replace employment type with full names
df['employment_type'].replace({'CT' : 'Contract', 'FL': 'Full', 'FT': 'Full Time', 'PT': 'Part Time'}, inplace=True)

# %%
# Assuming the dataframe is df3
df3=df.groupby('employment_type')['salary'].mean()
df3
# Out:
# employment_type
# Contract     184000.000000
# Full          48000.000000
# Full Time    331124.622449
# Part Time     85476.000000
# Name: salary, dtype: float64

# %%
#Plotting the data
df3.plot()
df3.plot(kind = 'line')
plt.title('AVERAGE SALARIES BY EMPLOYEES TYPE')
# Out:
# Text(0.5, 1.0, 'AVERAGE SALARIES BY EMPLOYEES TYPE')

# %% [markdown]
# Full-time workers earn more salary compared to other employees. They appear to offer the highest average salary, with an average of approximately 331,125.
# Contract employment type offers a lower average salary of 184,000, this could be attributed to factors such as limited duration of employment, lack of benefits typically associated with full-time roles.

# %% [markdown]
# ### COMPANY SIZE BY AVERAGE SALARY

# %%
# Is there a correlation between company size and average salary?
df.groupby('company_size')['salary'].mean()

# Replace employment type with full names
df['company_size'].replace({'L': 'Large', 'M': 'Medium', 'S': 'Small'}, inplace=True)

# %%
# Assuming the dataframe is df4
df4= df.groupby('company_size')['salary'].mean()
df4
# Out:
# company_size
# Large     593695.818182
# Medium    146522.500000
# Small     377710.012048
# Name: salary, dtype: float64

# %%
# Visualize the data using a pie chart
df4.plot()
df4.plot(kind = 'pie', autopct = '%2.1f%%')
salary= [593695.818182,  146522.500000, 377710.012048]
plt.title('AVERAGE SALARY BY COMPANY SIZE')
# Out:
# Text(0.5, 1.0, 'AVERAGE SALARY BY COMPANY SIZE')

# %% [markdown]
# Employees in large companies enjoy the highest average salary, constituting the majority (53.1%) of the workforce.Small companies also offer competitive average salaries, comprising a significant portion (33.8%) of the total workforce.Employees in medium-sized companies have notably lower average salaries, representing the smallest portion (13.1%) of the workforce.

# %% [markdown]
# ### WORK YEAR BY EXPERIENCE LEVEL

# %%
# Is there a trend in the distribution of experience levels over the years covered by the dataset?
df.groupby(['work_year', 'experience_level']).size()

# Replace experience levels with full names
df['experience_level'].replace(
    {'EN': 'Entry Level', 'EX': 'Executive Level', 'MI': 'Mid Level', 'SE': 'Senior Level'}, inplace=True)

# %%
# Assuming the dataframe is df5
df5=df.groupby(['work_year', 'experience_level']).size()
df5
# Out:
# work_year  experience_level
# 2020       Entry Level          20
#            Executive Level       2
#            Mid Level            32
#            Senior Level         18
# 2021       Entry Level          47
#            Executive Level      11
#            Mid Level            90
#            Senior Level         69
# 2022       Entry Level          21
#            Executive Level      13
#            Mid Level            91
#            Senior Level        193
# dtype: int64

# %%
# Plotting the DataFrame
df5.plot()
df5.plot(kind = 'bar')
plt.ylabel= ('Total')
plt.title('TRENDS IN EMPLOYEE DISTRIBUTION BY EXPERIENCE LEVEL OVER THE THREE YEARS (2020-2022)')
# Out:
# Text(0.5, 1.0, 'TRENDS IN EMPLOYEE DISTRIBUTION BY EXPERIENCE LEVEL OVER THE THREE YEARS (2020-2022)')

# %% [markdown]
# There has been a noticeable increase in the number of employees over the years from 2020 to 2022. The number of employees in Entry-Level positions increases from 20 in 2020 to 21 in 2022, while Mid-Level positions witness a more substantial growth from 32 in 2020 to 91 in 2022. While there were 18 employees in Senior-Level positions in 2020, this number increases substantially to 193 in 2022, indicating a remarkable growth or restructuring in the organization's leadership or senior management roles.

# %% [markdown]
# ### RELATIONSHIP BETWEEN COMPANY SIZE AND REMOTE RATIO

# %%
# Is there a relationship between company size and the frequency of remote work?
# Group by 'company_size' and 'remote_ratio' and calculate the proportions
df.groupby('company_size')['remote_ratio'].size()

# Replace company size with full names
df['company_size'].replace({'L': 'Large', 'M': 'Medium', 'S': 'Small'}, inplace=True)

# %%
# Assuming the datadrame is df6
df6 = df.groupby(['company_size', 'remote_ratio']).size() / df.groupby('company_size').size()
df['company_size'].replace({'L': 'Large', 'M': 'Medium', 'S': 'Small'}, inplace=True)
# Out:
# company_size  remote_ratio
# Large         0               0.161616
#               50              0.303030
#               100             0.535354
# Medium        0               0.242331
#               50              0.064417
#               100             0.693252
# Small         0               0.192771
#               50              0.216867
#               100             0.590361
# dtype: float64

# %%
df6.plot(kind = 'pie', autopct = '%0.01f%%')
plt.title('PROPORTION OF REMOTE WORK RATIOS BY COMPANY SIZE')
# Out:
# Text(0.5, 1.0, 'PROPORTION OF REMOTE WORK RATIOS BY COMPANY SIZE')

# %% [markdown]
# Large companies show a diverse distribution of remote work ratios, with approximately 5.4% having no remote work, 10.1% having a 50% remote work ratio, and 17.8% having fully remote setups.
# Medium-sized companies predominantly have fully remote setups, with approximately 23.1% of them adopting this model, while around 8.1% have no remote work and 2.1% have a 50% remote work ratio.
# Small companies also exhibit a significant trend towards fully remote setups, with approximately 19.7% having fully remote arrangements. Around 6.4% have no remote work, and 7.2% have a 50% remote work ratio.

# %% [markdown]
# ### DISTRIBUTION OF SALARIES ACCROSS DIFFERENT JOB TITLES

# %%
# What is the average salary earned in dollars for all job titles
average_salary = df['salary_in_usd'].mean()

# Print the result
print("Average salary in USD for all job titles:", average_salary)
# Out:
# Average salary in USD for all job titles: 112297.86985172982

# %%
# How does the distribution of salaries vary across different job titles?
df.groupby('job_title')['salary_in_usd'].sum().sort_values(ascending=False)
# Out:
# job_title
# Data Scientist                              15470860
# Data Engineer                               14879700
# Data Analyst                                 9010627
# Machine Learning Engineer                    4300086
# Data Architect                               1956613
# Data Science Manager                         1899942
# Research Scientist                           1744312
# Principal Data Scientist                     1506697
# Director of Data Science                     1365518
# Machine Learning Scientist                   1267300
# Principal Data Engineer                       985000
# Data Analytics Manager                        889940
# Applied Data Scientist                        878275
# Lead Data Engineer                            838347
# Head of Data                                  800813
# ML Engineer                                   705024
# Analytics Engineer                            700000
# ...

# %%
# Assuming df7 is the Dataframe
df7=df.groupby('job_title')['salary_in_usd'].sum().sort_values(ascending=False)
df7
# Out:
# job_title
# Data Scientist                              15470860
# Data Engineer                               14879700
# Data Analyst                                 9010627
# Machine Learning Engineer                    4300086
# Data Architect                               1956613
# Data Science Manager                         1899942
# Research Scientist                           1744312
# Principal Data Scientist                     1506697
# Director of Data Science                     1365518
# Machine Learning Scientist                   1267300
# Principal Data Engineer                       985000
# Data Analytics Manager                        889940
# Applied Data Scientist                        878275
# Lead Data Engineer                            838347
# Head of Data                                  800813
# ML Engineer                                   705024
# Analytics Engineer                            700000
# ...

# %%
# Visualize the data
df7.plot(kind='bar', figsize=(10, 6))
plt.title('TOTAL SALARIES ACROSS JOB TITLES')
plt.xlabel('Job Title')
plt.show()

# %% [markdown]
# The data scientist and data engineer roles emerge as the top-earning job titles, with total salaries of 15,470,860 and 14,879,700, respectively.This underscores the importance of data-driven decision-making and the growing reliance on data technologies in various industries.

# %% [markdown]
# ### AVERAGE SALARY TREND OVER THE YEARS

# %%
# Has there been any noticeable trend in the average salary over the years?
df.groupby('work_year')['salary_in_usd'].mean()

# %%
# Assuming the dataframe is named df8
df8=df.groupby('work_year')['salary_in_usd'].mean()
df8
# Out:
# work_year
# 2020     95813.000000
# 2021     99853.792627
# 2022    124522.006289
# Name: salary_in_usd, dtype: float64

# %%
#Plot a bar chart to visualize the Average salary trend over the years
df8.plot
df8.plot(kind='bar', figsize=(10, 6))
plt.title('AVERAGE SALARY TREND OVER THE YEARS')
plt.xlabel('Job Title')
plt.show()

# %% [markdown]
# The data reveals an increasing trend in average salaries across the years 2020 to 2022.
# In 2020, the average salary was 95,813, which increased to 99,853 in 2021 and further to 124,522 in 2022.

# %% [markdown]
# ### RELATIONSHIP BETWEEN REMOTE RATIO AND SALARY

# %%
# Is there a correlation between the remote work ratio and average salary?
# Group by 'remote_ratio' and 'salary_in_usd' to calculate the maximum salaries
df.groupby('remote_ratio')['salary_in_usd'].max()

# %%
# Assuming df9 is the DataFrame
df9=df.groupby('remote_ratio')['salary_in_usd'].max()
df9
# Out:
# remote_ratio
# 0      450000
# 50     423000
# 100    600000
# Name: salary_in_usd, dtype: int64

# %%
# Plot a scatter plot
plt.figure(figsize=(6, 5))
plt.scatter(df9.index, df9.values)
plt.title('MAXIMUM SALARY BY REMOTE WORK RATIO')
plt.xlabel('remote_ratio')
plt.grid(True)
plt.show()

# %% [markdown]
# For employees with no remote work option (remote_ratio = 0), the maximum salary is 450,000.
# Employees with a 50% remote work option have a maximum salary of 423,000.
# Those with fully remote setups (remote_ratio = 100) have the highest maximum salary of 600,000.

# %% [markdown]
# ### PROPORTION OF EMPLOYMENT TYPES FROM (2020-2022)

# %%
# Group by 'work_year' and 'employment_type' and calculate the counts
employment_type_counts = df.groupby(['work_year', 'employment_type']).size()

# Group by 'work_year' and calculate the total count of employees for each year
total_employees_per_year = df.groupby('work_year').size()

# Calculate the proportion of each employment type within each year
employment_type_proportion = employment_type_counts.div(total_employees_per_year, level='work_year')

# Print the result
print(employment_type_proportion)
# Out:
# work_year  employment_type
# 2020       Contract           0.013889
#            Full               0.013889
#            Full Time          0.944444
#            Part Time          0.027778
# 2021       Contract           0.013825
#            Full               0.009217
#            Full Time          0.949309
#            Part Time          0.027650
# 2022       Contract           0.003145
#            Full               0.003145
#            Full Time          0.987421
#            Part Time          0.006289
# dtype: float64

# %%
# Assuming df10 is the dataframe
df10= employment_type_proportion
df10
# Out:
# work_year  employment_type
# 2020       Contract           0.013889
#            Full               0.013889
#            Full Time          0.944444
#            Part Time          0.027778
# 2021       Contract           0.013825
#            Full               0.009217
#            Full Time          0.949309
#            Part Time          0.027650
# 2022       Contract           0.003145
#            Full               0.003145
#            Full Time          0.987421
#            Part Time          0.006289
# dtype: float64

# %%
# Define colors for each employment type
colors = ['blue', 'green', 'red']

# Plot a bar chart for each year
df10.plot(kind = 'bar', color=colors)
plt.title('PROPORTION OF EMPLOYMENT TYPES FROM (2020-2022)')
# Out:
# Text(0.5, 1.0, 'PROPORTION OF EMPLOYMENT TYPES FROM (2020-2022)')

# %% [markdown]
# Across all three years (2020-2022), full-time employment consistently represents the majority proportion of employment types.
# In 2020, full-time employment accounts for approximately 94.4% of the workforce, followed by part-time employment (2.8%), contract (1.4%), and full employment (1.4%).
# Similarly, in 2021 and 2022, full-time employment maintains its dominance, representing around 94.9% and 98.7% of the workforce, respectively.

# %% [markdown]
# ##  CONCLUSION

# %% [markdown]
# Salary Analysis:
#
# Salaries vary significantly across different job roles, experience levels, and employment types.
# Executive and mid-level positions tend to have higher average salaries compared to entry-level and senior-level roles.
# Full-time employment generally offers higher average salaries compared to part-time or contract employment.
#
# Job Role Analysis:
#
# Data-related roles such as Data Scientist, Data Engineer, and Data Analyst are among the top-paid positions.
#
# Experience Level Trends:
#
# There is a clear trend of increasing salaries with higher experience levels, with mid-level employees earning the highest average salaries.
# Entry-level and senior-level employees tend to have lower average salaries compared to mid-level and executive-level employees.
#
# Company Size Analysis:
#
# Large companies offer the highest average salaries, followed by small and medium-sized companies.
#
# Remote Work Analysis:
#
# Employees with fully remote work options tend to have higher maximum salaries compared to those with partial or no remote work options. This indicates that remote work policies may influence salary levels within organizations.
#
# Employment Type Analysis:
#
# Full-time employment dominates the workforce, representing the majority proportion across all years.
#
# Overall Trends:
#
# Overall, there is stability in the distribution of employment types, salary levels, and job role preferences over the analyzed period.
# However, there are discernible trends such as increasing salaries with higher experience levels and the dominance of full-time employment.
